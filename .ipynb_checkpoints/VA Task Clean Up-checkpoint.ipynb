# %%
import pandas as pd
import polars as pl

# df = pd.read_csv(
#     "VA list - Ecommerce and Healthcare.csv",
#     engine="python",
#     on_bad_lines="skip"
# )

# print(df.head(10))

data = pl.read_csv(
    "VA list - Ecommerce and Healthcare.csv",
    infer_schema_length=None,          # scan entire file for schema
    null_values=["NULL", "N/A", ""],
    ignore_errors=True,                # skip bad rows
    truncate_ragged_lines=True,        # FIX: uneven column counts
    encoding="utf8-lossy",              # FIX: bad characters
    try_parse_dates=True
)

print(data.head(10))
# Out:
# shape: (10, 42)
# ┌──────────────┬──────────────┬──────────────┬─────────────┬───┬─────────────┬─────────────┬─────────────┬─────────────┐
# │ full_name    ┆ region       ┆ role         ┆ csm_notes   ┆ … ┆ _duplicated ┆ _duplicated ┆ _duplicated ┆ _duplicated │
# │ ---          ┆ ---          ┆ ---          ┆ ---         ┆   ┆ _33         ┆ _34         ┆ _35         ┆ _36         │
# │ str          ┆ str          ┆ str          ┆ str         ┆   ┆ ---         ┆ ---         ┆ ---         ┆ ---         │
# │              ┆              ┆              ┆             ┆   ┆ str         ┆ str         ┆ str         ┆ str         │
# ╞══════════════╪══════════════╪══════════════╪═════════════╪═══╪═════════════╪═════════════╪═════════════╪═════════════╡
# │ AANCHAL      ┆ India        ┆ Ecommerce    ┆ Tasks that  ┆ … ┆ null        ┆ null        ┆ null        ┆ null        │
# │ KHANDELWAL   ┆              ┆ Assistant FT ┆ your new    ┆   ┆             ┆             ┆             ┆             │
# │              ┆              ┆              ┆ CSR will b… ┆   ┆             ┆             ┆             ┆             │
# │ AASHIMA      ┆ India        ┆ Ecommerce    ┆ ndustry:    ┆ … ┆ Writing des ┆ uploading   ┆ Facebook    ┆ instagram�" │
# │ SUTHAR       ┆              ┆ Assistant PT ┆ Ecommerce   ┆   ┆ criptions   ┆ pictures to ┆             ┆             │
# │              ┆              ┆              ┆ Client l…   ┆   ┆             ┆ our back…   ┆             ┆             │
# │ ADESHOLA     ┆ Philippines  ┆ Healthcare   ┆ Company     ┆ … ┆ null        ┆ null        ┆ null        ┆ null        │
# │ ADEYINKA     ┆              ┆ VA Full Time ┆ name:       ┆   ┆             ┆             ┆             ┆             │
# │              ┆              ┆ Expert       ┆ CINCHMD     ┆   ┆             ┆             ┆             ┆             │
# │              ┆              ┆              ┆ Solution…   ┆   ┆             ┆             ┆             ┆             │
# │ ADITI TIWARI ┆ India        ┆ Ecommerce    ┆ Business    ┆ … ┆ null        ┆ null        ┆ null        ┆ null        │
# │              ┆              ┆ Assistant FT ┆ Name:       ┆   ┆             ┆             ┆             ┆             │
# │              ┆              ┆              ┆ �Challenger ┆   ┆             ┆             ┆             ┆             │
# │              ┆              ┆              ┆ Sal…        ┆   ┆             ┆             ┆             ┆             │
# │ ADRIAN       ┆ Latin        ┆ Healthcare   ┆ Company     ┆ … ┆ null        ┆ null        ┆ null        ┆ null        │
# │ VENEGAS      ┆ America And  ┆ VA Full Time ┆ name:       ┆   ┆             ┆             ┆             ┆             │
# │              ┆ Mexico       ┆              ┆ Lifeline    ┆   ┆             ┆             ┆             ┆             │
# │              ┆              ┆              ┆ ABA    …    ┆   ┆             ┆             ┆             ┆             │
# │ AILEEN TAGLE ┆ Philippines  ┆ Healthcare   ┆ Company     ┆ … ┆ null        ┆ null        ┆ null        ┆ null        │
# │              ┆              ┆ VA Full Time ┆ name:       ┆   ┆             ┆             ┆             ┆             │
# │              ┆              ┆ Mid          ┆ Primary     ┆   ┆             ┆             ┆             ┆             │
# │              ┆              ┆              ┆ Care Cli…   ┆   ┆             ┆             ┆             ┆             │
# │ AISHITA      ┆ India        ┆ Ecommerce    ┆ Company     ┆ … ┆ null        ┆ null        ┆ null        ┆ null        │
# │ SINGH        ┆              ┆ Assistant PT ┆ name: Mat   ┆   ┆             ┆             ┆             ┆             │
# │              ┆              ┆              ┆ Sanders     ┆   ┆             ┆             ┆             ┆             │
# │              ┆              ┆              ┆ Inte…       ┆   ┆             ┆             ┆             ┆             │
# │ AISHWARYA    ┆ India        ┆ Ecommerce    ┆ Client      ┆ … ┆ null        ┆ null        ┆ null        ┆ null        │
# │ AGRAWAL      ┆              ┆ Assistant FT ┆ wants to    ┆   ┆             ┆             ┆             ┆             │
# │              ┆              ┆              ┆ interview   ┆   ┆             ┆             ┆             ┆             │
# │              ┆              ┆              ┆ top …       ┆   ┆             ┆             ┆             ┆             │
# │ AKANSHA      ┆ India        ┆ Ecommerce    ┆ Business    ┆ … ┆ null        ┆ null        ┆ null        ┆ null        │
# │ SAXENA       ┆              ┆ Assistant PT ┆ Name:� EV   ┆   ┆             ┆             ┆             ┆             │
# │              ┆              ┆              ┆ 20  ��      ┆   ┆             ┆             ┆             ┆             │
# │              ┆              ┆              ┆ Ind…        ┆   ┆             ┆             ┆             ┆             │
# │ ALESSANDRA   ┆ Philippines  ┆ Healthcare   ┆ WingPlan    ┆ … ┆ null        ┆ null        ┆ null        ┆ null        │
# │ NICOLE       ┆              ┆ VA Full Time ┆ Subscriptio ┆   ┆             ┆             ┆             ┆             │
# │ SANCHEZ      ┆              ┆              ┆ n: �Full T… ┆   ┆             ┆             ┆             ┆             │
# └──────────────┴──────────────┴──────────────┴─────────────┴───┴─────────────┴─────────────┴─────────────┴─────────────┘

# %%
import polars as pl

data = data.with_columns(
    pl.when(pl.col("csm_notes").is_null())
      .then("")
      .otherwise(
          pl.col("csm_notes")
            .str.replace_all(r"<!--.*?-->", "")
            .str.replace_all(r"<[^>]+>", "")
            .str.replace_all(r"&nbsp;", " ")
            .str.replace_all(r"\s+", " ")
            .str.strip_chars()
      )
      .alias("clean_notes")
)

print(data.head(10))
# Out:
# shape: (10, 43)
# ┌──────────────┬──────────────┬──────────────┬─────────────┬───┬─────────────┬─────────────┬─────────────┬─────────────┐
# │ full_name    ┆ region       ┆ role         ┆ csm_notes   ┆ … ┆ _duplicated ┆ _duplicated ┆ _duplicated ┆ clean_notes │
# │ ---          ┆ ---          ┆ ---          ┆ ---         ┆   ┆ _34         ┆ _35         ┆ _36         ┆ ---         │
# │ str          ┆ str          ┆ str          ┆ str         ┆   ┆ ---         ┆ ---         ┆ ---         ┆ str         │
# │              ┆              ┆              ┆             ┆   ┆ str         ┆ str         ┆ str         ┆             │
# ╞══════════════╪══════════════╪══════════════╪═════════════╪═══╪═════════════╪═════════════╪═════════════╪═════════════╡
# │ AANCHAL      ┆ India        ┆ Ecommerce    ┆ Tasks that  ┆ … ┆ null        ┆ null        ┆ null        ┆ Tasks that  │
# │ KHANDELWAL   ┆              ┆ Assistant FT ┆ your new    ┆   ┆             ┆             ┆             ┆ your new    │
# │              ┆              ┆              ┆ CSR will b… ┆   ┆             ┆             ┆             ┆ CSR will b… │
# │ AASHIMA      ┆ India        ┆ Ecommerce    ┆ ndustry:    ┆ … ┆ uploading   ┆ Facebook    ┆ instagram�" ┆ ndustry:    │
# │ SUTHAR       ┆              ┆ Assistant PT ┆ Ecommerce   ┆   ┆ pictures to ┆             ┆             ┆ Ecommerce   │
# │              ┆              ┆              ┆ Client l…   ┆   ┆ our back…   ┆             ┆             ┆ Client      │
# │              ┆              ┆              ┆             ┆   ┆             ┆             ┆             ┆ loca…       │
# │ ADESHOLA     ┆ Philippines  ┆ Healthcare   ┆ Company     ┆ … ┆ null        ┆ null        ┆ null        ┆ Company     │
# │ ADEYINKA     ┆              ┆ VA Full Time ┆ name:       ┆   ┆             ┆             ┆             ┆ name:       │
# │              ┆              ┆ Expert       ┆ CINCHMD     ┆   ┆             ┆             ┆             ┆ CINCHMD     │
# │              ┆              ┆              ┆ Solution…   ┆   ┆             ┆             ┆             ┆ Solution…   │
# │ ADITI TIWARI ┆ India        ┆ Ecommerce    ┆ Business    ┆ … ┆ null        ┆ null        ┆ null        ┆ Business    │
# │              ┆              ┆ Assistant FT ┆ Name:       ┆   ┆             ┆             ┆             ┆ Name:       │
# │              ┆              ┆              ┆ �Challenger ┆   ┆             ┆             ┆             ┆ �Challenger │
# │              ┆              ┆              ┆ Sal…        ┆   ┆             ┆             ┆             ┆ Sal…        │
# │ ADRIAN       ┆ Latin        ┆ Healthcare   ┆ Company     ┆ … ┆ null        ┆ null        ┆ null        ┆ Company     │
# │ VENEGAS      ┆ America And  ┆ VA Full Time ┆ name:       ┆   ┆             ┆             ┆             ┆ name:       │
# │              ┆ Mexico       ┆              ┆ Lifeline    ┆   ┆             ┆             ┆             ┆ Lifeline    │
# │              ┆              ┆              ┆ ABA    …    ┆   ┆             ┆             ┆             ┆ ABA Cli…    │
# │ AILEEN TAGLE ┆ Philippines  ┆ Healthcare   ┆ Company     ┆ … ┆ null        ┆ null        ┆ null        ┆ Company     │
# │              ┆              ┆ VA Full Time ┆ name:       ┆   ┆             ┆             ┆             ┆ name:       │
# │              ┆              ┆ Mid          ┆ Primary     ┆   ┆             ┆             ┆             ┆ Primary     │
# │              ┆              ┆              ┆ Care Cli…   ┆   ┆             ┆             ┆             ┆ Care Cli…   │
# │ AISHITA      ┆ India        ┆ Ecommerce    ┆ Company     ┆ … ┆ null        ┆ null        ┆ null        ┆ Company     │
# │ SINGH        ┆              ┆ Assistant PT ┆ name: Mat   ┆   ┆             ┆             ┆             ┆ name: Mat   │
# │              ┆              ┆              ┆ Sanders     ┆   ┆             ┆             ┆             ┆ Sanders     │
# │              ┆              ┆              ┆ Inte…       ┆   ┆             ┆             ┆             ┆ Inte…       │
# │ AISHWARYA    ┆ India        ┆ Ecommerce    ┆ Client      ┆ … ┆ null        ┆ null        ┆ null        ┆ Client      │
# │ AGRAWAL      ┆              ┆ Assistant FT ┆ wants to    ┆   ┆             ┆             ┆             ┆ wants to    │
# │              ┆              ┆              ┆ interview   ┆   ┆             ┆             ┆             ┆ interview   │
# │              ┆              ┆              ┆ top …       ┆   ┆             ┆             ┆             ┆ top …       │
# │ AKANSHA      ┆ India        ┆ Ecommerce    ┆ Business    ┆ … ┆ null        ┆ null        ┆ null        ┆ Business    │
# │ SAXENA       ┆              ┆ Assistant PT ┆ Name:� EV   ┆   ┆             ┆             ┆             ┆ Name:� EV   │
# │              ┆              ┆              ┆ 20  ��      ┆   ┆             ┆             ┆             ┆ 20 ��       │
# │              ┆              ┆              ┆ Ind…        ┆   ┆             ┆             ┆             ┆ Indus…      │
# │ ALESSANDRA   ┆ Philippines  ┆ Healthcare   ┆ WingPlan    ┆ … ┆ null        ┆ null        ┆ null        ┆ WingPlan    │
# │ NICOLE       ┆              ┆ VA Full Time ┆ Subscriptio ┆   ┆             ┆             ┆             ┆ Subscriptio │
# │ SANCHEZ      ┆              ┆              ┆ n: �Full T… ┆   ┆             ┆             ┆             ┆ n: �Full T… │
# └──────────────┴──────────────┴──────────────┴─────────────┴───┴─────────────┴─────────────┴─────────────┴─────────────┘

# %%
# Explode tasks and keep related columns
tasks_df = (
    data
    .select([
        "full_name",
        "region",
        "role",
        "clean_notes"
    ])
    .drop_nulls("clean_notes")              # drop null tasks
)

print(tasks_df.head(10))
# Out:
# ---------------------------------------------------------------------------
# InvalidOperationError                     Traceback (most recent call last)
# Cell In[4], line 10
#       1 # Explode tasks and keep related columns
#       2 tasks_df = (
#       3     data
#       4     .select([
#       5         "full_name",
#       6         "region",
#       7         "role",
#       8         "clean_notes"
#       9     ])
# ---> 10     .explode("clean_notes")                # explode list column
#      11     .rename({"clean_notes": "clean_notes"})       # rename column
#      12     .drop_nulls("clean_notes")              # drop null tasks
#      13 )
#      15 print(tasks_df.head(10))
#
# File C:\Py313\Lib\site-packages\polars\dataframe\frame.py:9105, in DataFrame.explode(self, columns, *more_columns)
#    9048 """
#    9049 Explode the dataframe to long format by exploding the given columns.
#    9050
#    (...)   9098 └─────────┴─────────┘
#    9099 """
#    9100 from polars.lazyframe.opt_flags import QueryOptFlags
#    9102 return (
#    9103     self.lazy()
#    9104     .explode(columns, *more_columns)
# -> 9105     .collect(optimizations=QueryOptFlags._eager())
#    9106 )
#
# File C:\Py313\Lib\site-packages\polars\_utils\deprecation.py:97, in deprecate_streaming_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#      93         kwargs["engine"] = "in-memory"
#      95     del kwargs["streaming"]
# ---> 97 return function(*args, **kwargs)
#
# File C:\Py313\Lib\site-packages\polars\lazyframe\opt_flags.py:328, in forward_old_opt_flags.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325         optflags = cb(optflags, kwargs.pop(key))  # type: ignore[no-untyped-call,unused-ignore]
#     327 kwargs["optimizations"] = optflags
# --> 328 return function(*args, **kwargs)
#
# File C:\Py313\Lib\site-packages\polars\lazyframe\frame.py:2415, in LazyFrame.collect(self, type_coercion, predicate_pushdown, projection_pushdown, simplify_expression, slice_pushdown, comm_subplan_elim, comm_subexpr_elim, cluster_with_columns, collapse_joins, no_optimization, engine, background, optimizations, **_kwargs)
#    2413 # Only for testing purposes
#    2414 callback = _kwargs.get("post_opt_callback", callback)
# -> 2415 return wrap_df(ldf.collect(engine, callback))
#
# InvalidOperationError: `explode` operation not supported for dtype `str`

# %%
# Export to CSV (Excel-compatible)
tasks_df.write_csv(
    "VA list - Ecommerce and Healthcare - Cleaned.csv",
    include_header=True
)
